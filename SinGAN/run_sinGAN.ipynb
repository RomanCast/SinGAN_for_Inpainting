# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('drive/My Drive/Projet_Académique/3A MVA/S1_ObjectRecognition/Project_Inpainting/SinGAN/')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sat Dec 12 14:06:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# You first need to downgrade the versions of `torch` and `torchvision` because the model is not compatible with newer versions of PyTorch.

# %%
# !pip install torch==1.4.0 torchvision==0.5.0

# %% [markdown]
# ###Train the model on a specific image

# %%
# !python main_train.py --input_name city1.png
# Out:
# Random Seed:  8472
# 7 scales to train
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block3): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
# ...

# %% [markdown]
# ###Perform inpainting on a modified image

# %%
# !python inpainting.py --input_name city1.png --ref_name city1_edit2.png --inpainting_start_scale 2 --fill mean
# Out:
# Random Seed:  5279
# Traceback (most recent call last):
#   File "inpainting.py", line 49, in <module>
#     ref = functions.fill_mask(opt, ref, mask)
#   File "/content/drive/My Drive/Projet_Académique/3A MVA/S1_ObjectRecognition/Project_Inpainting/SinGAN/SinGAN/functions.py", line 363, in fill_mask
#     mean = ref[mask==0].mean(1)
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)
